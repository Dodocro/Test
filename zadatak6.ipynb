# %%
import networkx as nx
import matplotlib.pyplot as plt

G=nx.DiGraph()

#Definiranje spojnica
G.add_edge(0,1)
G.add_edge(0,3)
G.add_edge(1,2)
G.add_edge(1,3)
G.add_edge(2,5)
G.add_edge(3,21)

G.add_edge(4,5)
G.add_edge(4,6)
G.add_edge(4,7)
G.add_edge(5,21)
G.add_edge(6,5)
G.add_edge(6,7)
G.add_edge(6,12)
G.add_edge(7,3)

G.add_edge(8,12)
G.add_edge(8,11)
G.add_edge(9,8)
G.add_edge(9,11)
G.add_edge(10,3)
G.add_edge(10,8)
G.add_edge(11,7)
G.add_edge(11,10)

G.add_edge(12,21)
G.add_edge(12,13)
G.add_edge(13,15)
G.add_edge(14,22)
G.add_edge(15,12)
G.add_edge(15,7)

G.add_edge(16,21)
G.add_edge(17,11)
G.add_edge(17,16)
G.add_edge(18,17)
G.add_edge(18,19)
G.add_edge(19,16)
G.add_edge(19,17)

G.add_edge(20,8)
G.add_edge(22,3)
G.add_edge(23,20)
G.add_edge(23,22)

#Definiranje imena spojnica
G.edge[0][1]['Tezina']='1'
G.edge[0][3]['Tezina']='1'
G.edge[1][2]['Tezina']='1'
G.edge[1][3]['Tezina']='2'
G.edge[2][5]['Tezina']='1'
G.edge[3][21]['Tezina']='1'

G.edge[4][5]['Tezina']='1'
G.edge[4][6]['Tezina']='2'
G.edge[4][7]['Tezina']='2'
G.edge[5][21]['Tezina']='1'
G.edge[6][5]['Tezina']='1'
G.edge[6][7]['Tezina']='1'
G.edge[6][12]['Tezina']='1'
G.edge[7][3]['Tezina']='2'

G.edge[8][12]['Tezina']='2'
G.edge[8][11]['Tezina']='2'
G.edge[9][8]['Tezina']='1'
G.edge[9][11]['Tezina']='1'
G.edge[10][3]['Tezina']='1'
G.edge[10][8]['Tezina']='3'
G.edge[11][7]['Tezina']='1'
G.edge[11][10]['Tezina']='1'

G.edge[12][21]['Tezina']='2'
G.edge[12][13]['Tezina']='3'
G.edge[13][15]['Tezina']='1'
G.edge[14][22]['Tezina']='1'
G.edge[15][12]['Tezina']='1'
G.edge[15][7]['Tezina']='3'

G.edge[16][21]['Tezina']='1'
G.edge[17][11]['Tezina']='2'
G.edge[17][16]['Tezina']='1'
G.edge[18][17]['Tezina']='1'
G.edge[18][19]['Tezina']='2'
G.edge[19][16]['Tezina']='1'
G.edge[19][17]['Tezina']='3'

G.edge[20][8]['Tezina']='4'
G.edge[22][3]['Tezina']='3'
G.edge[23][20]['Tezina']='2'
G.edge[23][22]['Tezina']='1'


#Definiranje imena kao atribut
G.node[0]['Ime']='RUM'
G.node[1]['Ime']='ALB'
G.node[2]['Ime']='ŠVI'
G.node[3]['Ime']='FRA'
G.node[4]['Ime']='UKR'
G.node[5]['Ime']='POLJ'
G.node[6]['Ime']='SJ IR'
G.node[7]['Ime']='NJ'
G.node[8]['Ime']='BEL'
G.node[9]['Ime']='ŠVE'
G.node[10]['Ime']='IRS'
G.node[11]['Ime']='IT'
G.node[12]['Ime']='WAL'
G.node[13]['Ime']='RUS'
G.node[14]['Ime']='ENG'
G.node[15]['Ime']='SLOV'
G.node[16]['Ime']='HRV'
G.node[17]['Ime']='ŠPA'
G.node[18]['Ime']='ČEŠ'
G.node[19]['Ime']='TUR'
G.node[20]['Ime']='MAĐ'
G.node[21]['Ime']='PORT'
G.node[22]['Ime']='ISL'
G.node[23]['Ime']='AUS'

pozicija = nx.spring_layout(G)

nx.draw(G,pozicija)

#Crtanje imena
imena_label = nx.get_node_attributes(G,'Ime')
nx.draw_networkx_labels(G,pozicija,labels = imena_label)

#Crtanje imena spojnica
spojnica_label = nx.get_edge_attributes(G,'Tezina')
nx.draw_networkx_edge_labels(G,pozicija, spojnica_label)

pr=nx.pagerank(G, alpha=0.85)
print(pr)
plt.show()
# Out:
# /opt/conda/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /opt/conda/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# ...
